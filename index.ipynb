# %%
import math
import datetime
import numpy as np
import pandas as pd

from bokeh.plotting import figure, output_file, show
from bokeh.models import ColumnDataSource, Grid, LinearAxis, Plot, Range1d
from bokeh.models import DatetimeTickFormatter
from bokeh.io import output_notebook

from sklearn import datasets, linear_model

output_notebook()

from bokeh.io import output_file
output_file('index.html')
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0d6d9419-93c4-4071-80ef-a5ce43506b16">Loading BokehJS ...</span>
#     </div>

# %%
# Load data
sets = {
    'hume': {
        'mu': pd.read_csv('stats_mymapper_hume_20170129.csv', sep=',',
                     parse_dates=['tidspunkt'],
                     index_col='tidspunkt'
                    ),
        'cc': pd.read_csv('stats_ccmapper_hume_20170129.csv', sep=',',
                     parse_dates=['tidspunkt'],
                     index_col='tidspunkt'
                    ),
        },
    'real': {
        'mu': pd.read_csv('stats_mymapper_real_20170129.csv', sep=',',
                     parse_dates=['tidspunkt'],
                     index_col='tidspunkt'
                    ),
        'cc': pd.read_csv('stats_ccmapper_real_20170129.csv', sep=',',
                     parse_dates=['tidspunkt'],
                     index_col='tidspunkt'
                    ),
    }
}

# Normalize date indices to not include time
for a in sets.values():
    for b in a.values():
        b.index = pd.DatetimeIndex(b.index).normalize()

# Establish a linear date index
dfi = pd.date_range('2016-08-24', periods=160, freq='D')

df = {}
for k, v in sets.items():

    # Concat the data from Mymapper and CCMapper into a new column
    df[k] = pd.DataFrame(index=dfi)
    df[k] = df[k].join(pd.concat([v['mu'], v['cc']], axis=0))
    
    # Add a numeric index in addition to the date index
    df[k]['idx'] = range(0, df[k].shape[0])
    
    # Drop rows with missing values (NaN)
    df[k] = df[k].dropna()

# %%
# CCMapper import didn't work properly between 2016-12-03 and 2017-01-19, so
# we smooth out those data a bit to avoid a rapid drop
for k, v in df.items():
    diff1 = df[k].loc['2016-12-03']['begreper'] - df[k].loc['2016-12-04']['begreper']
    diff2 = df[k].loc['2017-01-19']['begreper'] - df[k].loc['2017-01-18']['begreper']
    print(diff1, diff2)

    sm = diff1 + np.arange(42) * (diff2 - diff1)/42.;
    df[k]['Smoothed'] = pd.concat([
        df[k].loc[:'2016-12-03']['begreper'],
        df[k].loc['2016-12-04':'2017-01-18']['begreper'] + sm ,
        df[k].loc['2017-01-19':]['begreper'],
        ])
# Out:
# -1.0 344.0
# 418.0 754.0

# %%
# Make a simple linear fit `y = ax + b` and add the `y` values to the dataframe
speed = {}
for k, v in df.items():
    x = df[k]['idx'].values.reshape(-1,1)
    y = df[k]['Smoothed'].values

    model = linear_model.LinearRegression()
    model.fit(x,y)
    speed[k] = model.coef_[0]
    print(k,': y=',speed[k],'x +', model.intercept_ )

    predictions = model.predict(x)
    x[:,0].shape
    predictions=pd.DataFrame(data=predictions, index=df[k].index.values, columns=['Fit'])

    df[k] = df[k].join(predictions, how='inner')
# Out:
# real : y= 14.7953500039 x + 1438.18746015
# hume : y= 35.5768830921 x + 3388.1994536

# %%
p = figure(title='Ferdigstilte begreper')
#p.line(joined_df['real'].index, joined_df['real']['begreper'], color='blue')
p.line(df['real'].index, df['real']['Smoothed'], color='brown')
p.line(df['real'].index, df['real']['Fit'],
       line_width=2, color="green",
       legend='Realfagstermer: {:.0f} begreper / dag'.format(speed['real'])
      )

#p.line(joined_df['hume'].index, joined_df['hume']['begreper'], color='orange')
p.line(df['real'].index, joined_df['hume']['Smoothed'], color='brown')
p.line(df['hume'].index, joined_df['hume']['Fit'], line_width=2, color="red",
      legend='Humord: {:.0f} begreper / dag'.format(speed['hume'])
      )

p.legend.location = 'top_left'

p.xaxis.formatter=DatetimeTickFormatter(
        hours=["%d %B %Y"],
        days=["%d %B %Y"],
        months=["%d %B %Y"],
        years=["%d %B %Y"],
    )

p.xaxis.major_label_orientation = math.pi/4

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="84747440-82da-497a-b54b-4b6b54b2c046"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("84747440-82da-497a-b54b-4b6b54b2c046").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("84747440-82da-497a-b54b-4b6b54b2c046");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '84747440-82da-497a-b54b-4b6b54b2c046' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b8dd8910-0a57-40c2-a796-b6fb25165119":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[153]},"y":{"__ndarray__":"...","dtype":"float64","shape":[153]}}},"id":"04cf0021-8881-499b-b0be-dbbeb7186af6","type":"ColumnDataSource"},{"attributes":{},"id":"d18a5027-1cc3-4db0-b311-6ac5c8b8db05","type":"BasicTickFormatter"},{"attributes":{},"id":"38f98a23-5e9f-4857-aed1-991fa632c771","type":"BasicTicker"},{"attributes":{"items":[{"id":"8b56d036-621b-4402-8941-aa34ff077198","type":"LegendItem"},{"id":"f6f1f17c-14b8-4bc4-a2e5-4b4b25dda2fe","type":"LegendItem"}],"location":"top_left","plot":{"id":"9a7b744f-a4c9-493b-a901-64017ea64a98","subtype":"Figure","type":"Plot"}},"id":"8e35bdf8-ccd5-44f6-8efe-725b66b6a6b0","type":"Legend"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"73644de4-0dcb-49d9-89f9-60d98a2ad104","type":"Line"},{"attributes":{"formatter":{"id":"8476ccdc-629c-44dd-93b6-149c02b294a5","type":"DatetimeTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"9a7b744f-a4c9-493b-a901-64017ea64a98","subtype":"Figure","type":"Plot"},"ticker":{"id":"2c9da50f-cc80-4d5d-b338-76962df9b21e","type":"BasicTicker"}},"id":"c1076dbc-4d59-4acc-b4fc-1fa4150c7c61","type":"LinearAxis"},{"attributes":{"overlay":{"id":"22fecdfb-dc4e-4249-9144-6c45ed1695b6","type":"BoxAnnotation"},"plot":{"id":"9a7b744f-a4c9-493b-a901-64017ea64a98","subtype":"Figure","type":"Plot"}},"id":"8ff08238-f6a1-4ba1-9b33-17cec3ccafef","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"9a7b744f-a4c9-493b-a901-64017ea64a98","subtype":"Figure","type":"Plot"}},"id":"81f3caa2-1e41-4401-b5f3-e5cf98bde3bb","type":"HelpTool"},{"attributes":{"plot":{"id":"9a7b744f-a4c9-493b-a901-64017ea64a98","subtype":"Figure","type":"Plot"}},"id":"887d14eb-3249-47b4-b249-b0f5b7a8e119","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"24b67464-4632-463f-8554-2a88e7fac378","type":"ColumnDataSource"},"glyph":{"id":"72fcbf5f-3a2e-4858-8189-bbe41cbc7297","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"73644de4-0dcb-49d9-89f9-60d98a2ad104","type":"Line"},"selection_glyph":null},"id":"41888362-6858-4055-b591-e52dec8960ef","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"9a7b744f-a4c9-493b-a901-64017ea64a98","subtype":"Figure","type":"Plot"}},"id":"529304bb-cfba-4332-9f37-07f1bd4156e3","type":"ResetTool"},{"attributes":{"plot":{"id":"9a7b744f-a4c9-493b-a901-64017ea64a98","subtype":"Figure","type":"Plot"},"ticker":{"id":"2c9da50f-cc80-4d5d-b338-76962df9b21e","type":"BasicTicker"}},"id":"946c0ed4-5f65-4129-977d-248fdbfa41e0","type":"Grid"},{"attributes":{"line_color":{"value":"brown"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3c183897-a332-41d4-ac80-154a630a4f13","type":"Line"},{"attributes":{"plot":null,"text":"Ferdigstilte begreper"},"id":"3a17463b-327d-4756-b8e1-2311e0f7ae12","type":"Title"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"3ed1db02-2b77-4409-8176-9ae657d64aa7","type":"Line"},{"attributes":{"label":{"value":"Humord: 36 begreper / dag"},"renderers":[{"id":"f42c992f-97f5-4db4-839f-ef8c63eff358","type":"GlyphRenderer"}]},"id":"f6f1f17c-14b8-4bc4-a2e5-4b4b25dda2fe","type":"LegendItem"},{"attributes":{"data_source":{"id":"04cf0021-8881-499b-b0be-dbbeb7186af6","type":"ColumnDataSource"},"glyph":{"id":"b5a76a69-5e73-4001-ab34-dcdc0a2988a3","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"3ed1db02-2b77-4409-8176-9ae657d64aa7","type":"Line"},"selection_glyph":null},"id":"f42c992f-97f5-4db4-839f-ef8c63eff358","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[153]},"y":{"__ndarray__":"...","dtype":"float64","shape":[153]}}},"id":"13137b54-b731-49c7-a ...

# %%
cl = {
    'hume': (9236./.51 - 9236),
    'real': (3822./.27 - 3822),
}

# OBS: Sommerferien er ikke med her, så man bør nok legge på noen uker

for k in cl.keys():
    dn = cl[k] / speed[k]
    expe = datetime.datetime.now() + datetime.timedelta(days=dn)
    print('{:s}: {:.0f} concepts left / {:.0f} concepts/day = {:.0f} days needed => complete at {:%Y-%m-%d}'.format(
            k, cl[k], speed[k], dn, expe))
# Out:
# real: 10334 concepts left / 15 concepts/day = 698 days needed => complete at 2018-12-29
# hume: 8874 concepts left / 36 concepts/day = 249 days needed => complete at 2017-10-06
